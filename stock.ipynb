# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stock = pd.read_csv(r'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')
stock
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...

# %%
stock.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stock.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
stock.shape
# Out:
# (2035, 8)

# %%
stock.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
stock.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
stock.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# ...

# %%
stock.corr()
# Out:
#                           Open      High       Low      Last     Close  \
# Open                  1.000000  0.999015  0.998825  0.997781  0.997840
# High                  0.999015  1.000000  0.998773  0.999155  0.999194
# Low                   0.998825  0.998773  1.000000  0.999051  0.999119
# Last                  0.997781  0.999155  0.999051  1.000000  0.999961
# Close                 0.997840  0.999194  0.999119  0.999961  1.000000
# Total Trade Quantity  0.385951  0.406405  0.380621  0.399328  0.398911
# Turnover (Lacs)       0.612877  0.630589  0.608502  0.624584  0.624213
#
#                       Total Trade Quantity  Turnover (Lacs)
# Open                              0.385951         0.612877
# High                              0.406405         0.630589
# Low                               0.380621         0.608502
# Last                              0.399328         0.624584
# Close                             0.398911         0.624213
# ...

# %%
stock.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2030    False
# 2031    False
# 2032    False
# 2033    False
# 2034    False
# Length: 2035, dtype: bool

# %%
stock.sum()
# Out:
# Date                    2018-09-282018-09-272018-09-262018-09-252018-0...
# Open                                                            304667.45
# High                                                             309305.4
# Low                                                             299743.15
# Last                                                             304180.1
# Close                                                            304131.3
# Total Trade Quantity                                           4753111658
# Turnover (Lacs)                                                7936460.45
# dtype: object

# %%
stock.mean()
# Out:
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_11984\2390091705.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stock.mean()
# Open                    1.497137e+02
# High                    1.519928e+02
# Low                     1.472939e+02
# Last                    1.494743e+02
# Close                   1.494503e+02
# Total Trade Quantity    2.335681e+06
# Turnover (Lacs)         3.899981e+03
# dtype: float64

# %%
stock.mode()
# Out:
#             Date   Open   High    Low   Last   Close  Total Trade Quantity  \
# 0     2010-07-21  148.0  135.0  141.0  154.2  141.90              839802.0
# 1     2010-07-22    NaN    NaN    NaN    NaN  154.85                   NaN
# 2     2010-07-23    NaN    NaN    NaN    NaN  155.55                   NaN
# 3     2010-07-26    NaN    NaN    NaN    NaN     NaN                   NaN
# 4     2010-07-27    NaN    NaN    NaN    NaN     NaN                   NaN
# ...          ...    ...    ...    ...    ...     ...                   ...
# 2030  2018-09-24    NaN    NaN    NaN    NaN     NaN                   NaN
# 2031  2018-09-25    NaN    NaN    NaN    NaN     NaN                   NaN
# 2032  2018-09-26    NaN    NaN    NaN    NaN     NaN                   NaN
# 2033  2018-09-27    NaN    NaN    NaN    NaN     NaN                   NaN
# 2034  2018-09-28    NaN    NaN    NaN    NaN     NaN                   NaN
#
#       Turnover (Lacs)
# 0              637.58
# ...

# %%
stock.median()
# Out:
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_11984\410430768.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stock.median()
# Open                        141.50
# High                        143.40
# Low                         139.60
# Last                        141.10
# Close                       141.25
# Total Trade Quantity    1783456.00
# Turnover (Lacs)            2512.03
# dtype: float64

# %%
stock.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
sns.heatmap(stock.corr())
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,10))  
sns.heatmap(stock.corr(),annot=True,cmap = "crest")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(stock.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(stock)

# %%
plt.figure(figsize=(16,9))
stock['High'].value_counts().head(8).plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,7))
stock['Total Trade Quantity'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(2)
plt.subplot(121)
sns.distplot(stock['Last'])
plt.subplot(122)
stock['Last'].plot.box(figsize=(15,5))
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
columns = ['High', 'Last', 'Total Trade Quantity','Turnover (Lacs)','Open']  # Replace with your actual column names

for column in columns:
    plt.figure(figsize=(25, 6))
    sns.countplot(x=stock[column], data=stock, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
stock.corr()
# Out:
#                           Open      High       Low      Last     Close  \
# Open                  1.000000  0.999015  0.998825  0.997781  0.997840
# High                  0.999015  1.000000  0.998773  0.999155  0.999194
# Low                   0.998825  0.998773  1.000000  0.999051  0.999119
# Last                  0.997781  0.999155  0.999051  1.000000  0.999961
# Close                 0.997840  0.999194  0.999119  0.999961  1.000000
# Total Trade Quantity  0.385951  0.406405  0.380621  0.399328  0.398911
# Turnover (Lacs)       0.612877  0.630589  0.608502  0.624584  0.624213
#
#                       Total Trade Quantity  Turnover (Lacs)
# Open                              0.385951         0.612877
# High                              0.406405         0.630589
# Low                               0.380621         0.608502
# Last                              0.399328         0.624584
# Close                             0.398911         0.624213
# ...

# %%
columns = ['High', 'Last', 'Total Trade Quantity','Turnover (Lacs)']
for column in columns:
    sns.violinplot(x='Open', y=column, data=stock)
    plt.xlabel('Open')
    plt.ylabel(column)
    plt.title(f'{column} vs Open')
    plt.show()

# %%
sns.pairplot(data=stock, hue='High', corner=True)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Total Trade Quantity", y="High", data=stock)
plt.title("Turnover (Lacs)", size=15)
plt.show()

# %%
features = ['High', 'Last', 'Total Trade Quantity','Turnover (Lacs)']
plt.figure(figsize=(10,5))
for i in range(0,len(features)):
    plt.subplot(1, len(features), i + 1)
    sns.boxplot(y=stock[features[i]], color='CornflowerBlue', orient='v')
    plt.tight_layout()
